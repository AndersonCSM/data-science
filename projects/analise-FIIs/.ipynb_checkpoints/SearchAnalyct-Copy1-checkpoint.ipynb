# %%
# importando as bibliotecas para a análise
import pandas as pd
import numpy as np
import os

# %%
# Lendo um arquivo
dt = pd.read_csv("planilhas_fundamentus_fii/teste_31_07_2023.csv")

# %%
# Visualizando os dados
dt
# Out:
#       papel            segmento  cotacao  ffo_yield  dividend_yield  \
# 0    AAZQ11   Títulos e Val Mob     9.38     0.0462          0.0880
# 1    ABCP11           Shoppings    71.90     0.1714          0.0764
# 2    AEFI11              Outros   174.90     0.0803          0.0000
# 3    AFCR11        Desconhecido   103.15     0.1821          0.0000
# 4    AFHI11   Títulos e Val Mob    96.15     0.1110          0.1367
# ..      ...                 ...      ...        ...             ...
# 413  XTED11  Lajes Corporativas     8.82    -0.0045          0.0000
# 414  YCHY11             Híbrido  1000.00     0.0125          0.0000
# 415  YUFI11         Residencial    80.01     0.0395          0.0484
# 416  ZAVI11             Híbrido   127.45     0.0575          0.0753
# 417  ZIFI11             Híbrido  1000.00    -0.0172          0.0000
#
#      p_sobre_vp  valor_de_mercado   liquidez  qtd_de_imoveis  preco_do_m2  \
# 0          0.97      2.254700e+08   942155.0             0.0         0.00
# ...

# %%
# Verificando se os dados estão corretos
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   papel             418 non-null    object
#  1   segmento          418 non-null    object
#  2   cotacao           418 non-null    float64
#  3   ffo_yield         418 non-null    float64
#  4   dividend_yield    418 non-null    float64
#  5   p_sobre_vp        418 non-null    float64
#  6   valor_de_mercado  418 non-null    float64
#  7   liquidez          418 non-null    float64
#  8   qtd_de_imoveis    418 non-null    float64
#  9   preco_do_m2       418 non-null    float64
#  10  aluguel_por_m2    418 non-null    float64
#  11  cap_rate          418 non-null    float64
#  12  vacancia_media    418 non-null    float64
# dtypes: float64(11), object(2)
# memory usage: 42.6+ KB

# %%
# Modificando uma configuração do pandas para melhorar a visualização de valores muito grandes
pd.set_option('display.float_format', '{:.4f}'.format)

# %%
# Removendo fundos com valores inconstantes
dt.replace([np.inf, -np.inf], np.nan, inplace=True)

dt.dropna(inplace=True)

# %%
# Visualizando os dados
dt
# Out:
#       papel            segmento   cotacao  ffo_yield  dividend_yield  \
# 0    AAZQ11   Títulos e Val Mob    9.3800     0.0462          0.0880
# 1    ABCP11           Shoppings   71.9000     0.1714          0.0764
# 2    AEFI11              Outros  174.9000     0.0803          0.0000
# 3    AFCR11        Desconhecido  103.1500     0.1821          0.0000
# 4    AFHI11   Títulos e Val Mob   96.1500     0.1110          0.1367
# ..      ...                 ...       ...        ...             ...
# 413  XTED11  Lajes Corporativas    8.8200    -0.0045          0.0000
# 414  YCHY11             Híbrido 1000.0000     0.0125          0.0000
# 415  YUFI11         Residencial   80.0100     0.0395          0.0484
# 416  ZAVI11             Híbrido  127.4500     0.0575          0.0753
# 417  ZIFI11             Híbrido 1000.0000    -0.0172          0.0000
#
#      p_sobre_vp  valor_de_mercado     liquidez  qtd_de_imoveis  preco_do_m2  \
# ...

# %%
# aplicando o filtro que o preço da cota deve ser menor que R$ 125,00 pois é o que eu disponho para comprar atualmente
dt = dt[dt.cotacao < 125]

# %%
# Aplicando filtro que o rendimento do fundo é maior do que ele provém de cota, permitindo estabilidade nos pagamentos
dt = dt[dt.ffo_yield >= dt.dividend_yield]

# %%
# Aplicando filtro para selecionar os fundos que apresentam ffo_yield > 0, dividend_yield > 0, p_sobre_vp > 0, valor_de_mercado > 0 e liquidez > 0
dt = dt[((dt.ffo_yield > 0) & (dt.dividend_yield > 0) & (dt.p_sobre_vp > 0) & (dt.valor_de_mercado > 0) & (dt.liquidez > 0))]

# %%
# Aplicando o filtro de que o p/vp seja menor do que 1, logo estária bom para comprar
dt = dt[dt.p_sobre_vp <= 1]

# %%
# Visualizando os dados
dt
# Out:
#       papel            segmento  cotacao  ffo_yield  dividend_yield  \
# 1    ABCP11           Shoppings  71.9000     0.1714          0.0764
# 8    AIEC11  Lajes Corporativas  71.5700     0.1268          0.1170
# 13   APTO11             Híbrido   9.9500     0.1304          0.1270
# 17   ASMT11             Híbrido  49.5300     0.1584          0.0899
# 18   ATSA11           Shoppings  66.0000     0.0192          0.0053
# ..      ...                 ...      ...        ...             ...
# 395  VTLT11           Logística  99.7000     0.1046          0.0970
# 396  VVCR11   Títulos e Val Mob  22.1300     0.5161          0.0473
# 406  XPCM11  Lajes Corporativas  13.5000     0.1378          0.1051
# 411  XPPR11              Outros  22.4000     0.1493          0.1130
# 412  XPSF11   Títulos e Val Mob   8.4000     0.1057          0.1016
#
#      p_sobre_vp  valor_de_mercado    liquidez  qtd_de_imoveis  preco_do_m2  \
# ...

# %%
# Ordenando por valor crescente da quantidade de cotas
dt = dt.sort_values(by='cotacao', ascending=True)

# %%
# Visualizando os dados
dt
# Out:
#       papel           segmento  cotacao  ffo_yield  dividend_yield  \
# 209  KNRE11        Residencial   0.5600     0.6244          0.4578
# 37   BLMR11  Títulos e Val Mob   7.5500     0.1147          0.1103
# 384  VIFI11  Títulos e Val Mob   8.3700     0.1096          0.0858
# 412  XPSF11  Títulos e Val Mob   8.4000     0.1057          0.1016
# 388  VIUR11             Outros   8.4800     0.1092          0.0957
# ..      ...                ...      ...        ...             ...
# 177  HUSC11             Outros 106.0000     0.1005          0.0956
# 27   BCIA11  Títulos e Val Mob 106.0000     0.0969          0.0899
# 247  NEWL11            Híbrido 115.0000     0.2157          0.0965
# 223  MALL11          Shoppings 115.5000     0.1520          0.0773
# 126  FVPQ11          Shoppings 117.1400     0.0869          0.0868
#
#      p_sobre_vp  valor_de_mercado     liquidez  qtd_de_imoveis  preco_do_m2  \
# 209      0.7400     10386400.0000   12865.0000          0.0000       0.0000
# ...

# %%
dt_recent = dt.copy()

# %% [markdown]
# # Criando um algoritmo para analisar todas as planilhas e criar uma tabela de frequência

# %%
# Criando a função tabela
def tabela(frequencia, dt):
    for nome in dt.papel:
        if nome not in frequencia:
            frequencia[nome] = 1
        else:
            frequencia[nome] += 1

    return frequencia

# %%
# caminho da pasta
path = 'planilhas_fundamentus_fii/'

# %%
# Percorrendo cada arquivo da pasta e criando a tabela de frequência

frequencia = {}

qtd_arquivos = 0 

for nome_arquivo in os.listdir(path):
    
    # Verificando se o arquivo é um arquivo csv
    if nome_arquivo.endswith(".csv"):
        
        # Concatenando o caminho para o arquivo para repassar ao Pandas
        arquivo = os.path.join(path, nome_arquivo)
        
        # Transformando em um Dataframe
        dt = pd.read_csv(arquivo)
        
        # Removendo fundos com valores inconstantes
        dt.replace([np.inf, -np.inf], np.nan, inplace=True)
        dt.dropna(inplace=True)
        
        # Aplicando filtro para selecionar os fundos que apresentam ffo_yield > 0, dividend_yield > 0, p_sobre_vp > 0, valor_de_mercado > 0 e liquidez > 0
        dt = dt[((dt.ffo_yield > 0) & (dt.dividend_yield > 0) & (dt.p_sobre_vp > 0) & (dt.valor_de_mercado > 0) & (dt.liquidez > 0))]

        
        # aplicando o filtro que o preço da cota deve ser menor que R$ 125,00 pois é o que eu disponho para comprar atualmente
        dt = dt[dt.cotacao < 125]
        
        # Aplicando filtro que o rendimento do fundo é maior do que ele provém de cota, permitindo estabilidade nos pagamentos
        dt = dt[dt.ffo_yield >= dt.dividend_yield]
        
        # Aplicando o filtro de que o p/vp seja menor do que 1, logo estária bom para comprar
        dt = dt[dt.p_sobre_vp <= 1]

        # Ordenando por valor crescente da quantidade de cotas
        dt = dt.sort_values(by='cotacao', ascending=True)

        frequencia = tabela(frequencia, dt)
        
        qtd_arquivos += 1

# %%
# descarto KNRE11 por pagar dividendos a cada 6 meses

frequencia
# Out:
# {'KNRE11': 5,
#  'BLMR11': 5,
#  'VIUR11': 5,
#  'XPSF11': 5,
#  'VIFI11': 5,
#  'KISU11': 5,
#  'GALG11': 4,
#  'NCRI11': 5,
#  'BTCI11': 5,
#  'APTO11': 5,
#  'NVHO11': 5,
#  'XPCM11': 5,
#  'EDGA11': 5,
#  'VVCR11': 5,
#  'XPPR11': 5,
#  'HOFC11': 5,
#  'CNES11': 1,
#  'SNLG11': 5,
#  'RBRD11': 5,
#  'SPTW11': 5,
#  'CXCE11B': 5,
#  'RBCO11': 5,
#  'VINO11': 5,
#  'RNGO11': 5,
#  'ASMT11': 5,
#  'RECT11': 5,
#  'PQAG11': 5,
#  'RBRS11': 5,
#  'RBRP11': 5,
#  'RELG11': 5,
#  'SARE11': 5,
#  'FIGS11': 5,
#  'HAAA11': 5,
#  'CJCT11': 5,
#  'BPML11': 5,
#  'ATSA11': 5,
#  'SEQR11': 5,
#  'GCFF11': 5,
#  'GLOG11': 5,
#  'RECX11': 5,
#  'AIEC11': 5,
#  'ABCP11': 5,
#  'BPFF11': 5,
#  'PATL11': 5,
#  'MAXR11': 5,
#  'JFLL11': 5,
#  'BCFF11': 5,
#  'CPFF11': 5,
#  'BBFO11': 5,
#  'BCRI11': 5,
#  'ITIP11': 5,
#  'ITIT11': 5,
#  'HFOF11': 5,
#  'QAMI11': 5,
#  'CXRI11': 5,
#  'JSRE11': 5,
#  'VCRR11': 5,
#  'VSHO11': 5,
#  'LUGG11': 5,
#  'HPDP11': 5,
#  'HREC11': 5,
#  'CXCO11': 5,
# ...

# %%
x = list(frequencia.keys())
y = list(frequencia.values())
dados = [x, y]

# %%
dt_freq = pd.DataFrame(data = dados)

# %%
dt_freq = dt_freq.transpose()

# %%
dt_freq.columns = ["nome","contagem"]

# %%
dt_freq
# Out:
#        nome contagem
# 0    KNRE11        5
# 1    BLMR11        5
# 2    VIUR11        5
# 3    XPSF11        5
# 4    VIFI11        5
# ..      ...      ...
# 97   FVPQ11        5
# 98   LVBI11        1
# 99   MGCR11        2
# 100  GTLG11        2
# 101  HSAF11        2
#
# [102 rows x 2 columns]

# %%
dt_freq = dt_freq[dt_freq.contagem >= qtd_arquivos]
dt_freq
# Out:
#       nome contagem
# 0   KNRE11        5
# 1   BLMR11        5
# 2   VIUR11        5
# 3   XPSF11        5
# 4   VIFI11        5
# ..     ...      ...
# 92  BCIA11        5
# 93  TMPS11        5
# 95  NEWL11        5
# 96  MALL11        5
# 97  FVPQ11        5
#
# [95 rows x 2 columns]

# %%
dt_recent = dt_recent[dt_recent.papel.isin(dt_freq.nome)]

# %%
dt_recent
# Out:
#       papel           segmento  cotacao  ffo_yield  dividend_yield  \
# 209  KNRE11        Residencial   0.5600     0.6244          0.4578
# 37   BLMR11  Títulos e Val Mob   7.5500     0.1147          0.1103
# 384  VIFI11  Títulos e Val Mob   8.3700     0.1096          0.0858
# 412  XPSF11  Títulos e Val Mob   8.4000     0.1057          0.1016
# 388  VIUR11             Outros   8.4800     0.1092          0.0957
# ..      ...                ...      ...        ...             ...
# 177  HUSC11             Outros 106.0000     0.1005          0.0956
# 27   BCIA11  Títulos e Val Mob 106.0000     0.0969          0.0899
# 247  NEWL11            Híbrido 115.0000     0.2157          0.0965
# 223  MALL11          Shoppings 115.5000     0.1520          0.0773
# 126  FVPQ11          Shoppings 117.1400     0.0869          0.0868
#
#      p_sobre_vp  valor_de_mercado     liquidez  qtd_de_imoveis  preco_do_m2  \
# 209      0.7400     10386400.0000   12865.0000          0.0000       0.0000
# ...

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Criação do relatório
profile = ProfileReport(dt_recent, title='Relatório do DataFrame', explorative=True)
# Out:
# C:\Users\Windows10\AppData\Local\Temp\ipykernel_10812\1839844388.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-08-01 17:51:19.211316&quot;&gt;&lt;title&gt;Relatório do DataFrame&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
dt_recent.nlargest(30, "dividend_yield")
# Out:
#       papel            segmento  cotacao  ffo_yield  dividend_yield  \
# 209  KNRE11         Residencial   0.5600     0.6244          0.4578
# 261  OURE11             Híbrido  84.3000     0.1581          0.1462
# 117  FLCR11   Títulos e Val Mob  93.4800     0.1526          0.1453
# 28   BCRI11   Títulos e Val Mob  76.3100     0.1782          0.1423
# 336  SADI11   Títulos e Val Mob  87.8000     0.3625          0.1318
# 267  PLCR11   Títulos e Val Mob  89.1600     0.2125          0.1303
# 390  VOTS11   Títulos e Val Mob  87.2500     0.2028          0.1290
# 13   APTO11             Híbrido   9.9500     0.1304          0.1270
# 77   CVBI11   Títulos e Val Mob  92.1900     0.1346          0.1265
# 315  RECR11   Títulos e Val Mob  88.0900     0.1346          0.1261
# 281  QAMI11             Híbrido  81.4800     0.2852          0.1248
# 188  ITIP11   Títulos e Val Mob  77.4000     0.2097          0.1213
# 335  RZTR11             Híbrido  94.0000     0.1563          0.1210
# ...
